# %%
import pandas as pd
import numpy as np

import bs4
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.service import Service
from selenium.webdriver.firefox.service import Service as FirefoxService

# Set the path to the GeckoDriver executable
gecko_driver_path = 'drivers/geckodriver.exe'

service = FirefoxService(executable_path=gecko_driver_path, log_path='geckodriver.log', log_output='moz:firefox')
options = webdriver.FirefoxOptions()

# Set the Firefox options
options.binary_location = 'C:/Program Files/Mozilla Firefox/firefox.exe'
options.add_argument('--disable-extensions')
options.add_argument('--disable-infobars')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--disable-gpu')
options.add_argument('--disable-popup-blocking')

bot = webdriver.Firefox(service=service, options=options)

# %% [markdown]
# ## First step: login to my account

# %%
# First Login
url = 'https://x.com/i/flow/login'

# visit the URL
bot.get(url)

# %% [markdown]
# ## Second lets go to a specific link

# %% [markdown]
# First build scroll_to_bottom function

# %%
import time

# Function to scroll to the bottom of the page
def scroll_to_bottom(driver, pause_time=3):
    last_height = driver.execute_script("return document.body.scrollHeight")
    
    while True:
        # Scroll down to the bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        
        # Wait to load page
        time.sleep(pause_time)
        
        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

# %%
# Define new URL
url = 'https://x.com/beeple/status/1586897188222803968'
bot.get(url)
scroll_to_bottom(bot)

# %%
# Lists to store comments and users
comments = []

# %%
soup = bs4.BeautifulSoup(bot.page_source, 'html.parser')
tweet_comments = soup.find_all('span', {'class': 'css-1jxf684 r-bcqeeo r-1ttztb7 r-qvutc0 r-poiln3', 'style': 'text-overflow: unset;','xpath': '1'})

# %%
if len(tweet_comments) > 0:
    for comment in tweet_comments:
        comments.append(comment.text)
    print(len(tweet_comments))

# %%
tweet_comments
# Out:
# []
